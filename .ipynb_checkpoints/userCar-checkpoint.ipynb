# %%
import csv

file_path = 'UserCarData.csv'

try:
    with open(file_path, mode='r', encoding='utf-8') as file:
        csv_reader = csv.reader(file)
        headers = next(csv_reader)  # Read header row
        print("Headers:", headers)

        for row in csv_reader:
            print(row)  # You can process each row here as needed

except FileNotFoundError:
    print(f"Error: The file at '{file_path}' was not found.")
except IOError:
    print("Error: There was an issue reading the file (possibly corrupted or inaccessible).")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Headers: ['Sales_ID', 'name', 'year', 'selling_price', 'km_driven', 'Region', 'State or Province', 'City', 'fuel', 'seller_type', 'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats', 'sold']
# ['1', 'Maruti', '2014', '450000', '145500', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.4', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['2', 'Skoda', '2014', '370000', '120000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '21.14', '1498', '103.52', '250Nm@ 1500-2500rpm', '5', 'Y']
# ['3', 'Honda', '2006', '158000', '140000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '17.7', '1497', '78', '12.7@ 2,700(kgm@ rpm)', '5', 'Y']
# ['4', 'Hyundai', '2010', '225000', '127000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23', '1396', '90', '22.4 kgm at 1750-2750rpm', '5', 'Y']
# ['5', 'Maruti', '2007', '130000', '120000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.1', '1298', '88.2', '11.5@ 4,500(kgm@ rpm)', '5', 'Y']
# ['6', 'Hyundai', '2017', '440000', '45000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.14', '1197', '81.86', '113.75nm@ 4000rpm', '5', 'Y']
# ['7', 'Maruti', '2007', '96000', '175000', 'West', 'California', 'Los Angeles', 'LPG', 'Individual', 'Manual', 'First_Owner', '17.3', '1061', '57.5', '7.8@ 4,500(kgm@ rpm)', '5', 'Y']
# ['8', 'Maruti', '2001', '45000', '5000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '16.1', '796', '37', '59Nm@ 2500rpm', '4', 'Y']
# ['9', 'Toyota', '2011', '350000', '90000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.59', '1364', '67.1', '170Nm@ 1800-2400rpm', '5', 'Y']
# ['10', 'Ford', '2013', '200000', '169000', 'Central', 'Texas', 'Houston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20', '1399', '68.1', '160Nm@ 2000rpm', '5', 'Y']
# ['11', 'Renault', '2014', '500000', '68000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '19.01', '1461', '108.45', '248Nm@ 2250rpm', '5', 'Y']
# ['12', 'Maruti', '2005', '92000', '100000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '17.3', '993', '60', '78Nm@ 4500rpm', '5', 'Y']
# ['13', 'Maruti', '2009', '280000', '140000', 'Central', 'Texas', 'Houston', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '19.3', '1248', '73.9', '190Nm@ 2000rpm', '5', 'Y']
# ['15', 'Maruti', '2009', '180000', '90000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.9', '1061', '67', '84Nm@ 3500rpm', '5', 'Y']
# ['16', 'Mahindra', '2016', '400000', '40000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.15', '1198', '82', '115Nm@ 3500-3600rpm', '5', 'Y']
# ['17', 'Maruti', '2016', '778000', '70000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '24.52', '1248', '88.5', '200Nm@ 1750rpm', '7', 'Y']
# ['18', 'Hyundai', '2012', '500000', '53000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '23', '1396', '90', '22.4 kgm at 1750-2750rpm', '5', 'Y']
# ['19', 'Maruti', '2002', '150000', '80000', 'Central', 'Texas', 'Dallas', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'Y']
# ['20', 'Hyundai', '2016', '680000', '100000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.54', '1396', '88.73', '219.7Nm@ 1500-2750rpm', '5', 'Y']
# ['21', 'Mahindra', '2011', '174000', '100000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '21', '1461', '64.1', '160Nm@ 2000rpm', '5', 'Y']
# ['22', 'Honda', '2017', '950000', '50000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '25.5', '1498', '98.6', '200Nm@ 1750rpm', '5', 'Y']
# ['23', 'Maruti', '2015', '525000', '40000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'First_Owner', '26.59', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['24', 'Maruti', '2012', '600000', '72000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.5', '1248', '88.8', '200Nm@ 1750rpm', '5', 'Y']
# ['25', 'Tata', '2018', '500000', '35000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.3', '1199', '83.81', '114Nm@ 3500rpm', '5', 'Y']
# ['26', 'Maruti', '2016', '575000', '45000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.4', '1197', '83.1', '115Nm@ 4000rpm', '5', 'Y']
# ['27', 'Maruti', '2017', '275000', '28000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'First_Owner', '24.7', '796', '47.3', '69Nm@ 3500rpm', '5', 'Y']
# ['28', 'Chevrolet', '2013', '300000', '70000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '18.2', '1248', '73.8', '172.5Nm@ 1750rpm', '7', 'Y']
# ['29', 'Maruti', '2009', '220000', '120000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.9', '1061', '67', '84Nm@ 3500rpm', '5', 'Y']
# ['30', 'Maruti', '2018', '254999', '25000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.8', '796', '34.2', '59Nm@ 2500rpm', '8', 'Y']
# ['31', 'Maruti', '2017', '670000', '70000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['33', 'Maruti', '2012', '150000', '35000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '14', '796', '35', '6.1kgm@ 3000rpm', '5', 'Y']
# ['34', 'Hyundai', '2018', '730000', '2388', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.6', '1197', '81.83', '114.7Nm@ 4000rpm', '5', 'Y']
# ['35', 'Maruti', '2017', '650000', '16200', 'West', 'Washington', 'Seattle', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['36', 'Maruti', '2019', '330000', '10000', 'West', 'Washington', 'Seattle', 'CNG', 'Individual', 'Manual', 'Second_Owner', '33.44', '796', '40.3', '60Nm@ 3500rpm', '4', 'Y']
# ['37', 'Maruti', '2019', '366000', '15000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'First_Owner', '23.95', '998', '67.1', '90Nm@ 3500rpm', '5', 'Y']
# ['38', 'Hyundai', '2019', '1149000', '5000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17', '1591', '121.3', '151Nm@ 4850rpm', '5', 'Y']
# ['39', 'Datsun', '2016', '150000', '42000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.63', '1198', '67', '104Nm@ 4000rpm', '5', 'Y']
# ['40', 'Tata', '2011', '425000', '60000', 'South', 'North Carolina', 'Charlotte', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '13.93', '2179', '138.03', '320Nm@ 1700-2700rpm', '7', 'Y']
# ['41', 'Maruti', '2012', '150000', '76000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.1', '796', '37', '59Nm@ 2500rpm', '4', 'Y']
# ['42', 'Jeep', '2019', '2100000', '5000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '16', '1368', '160.77', '250Nm@ 1750-2500rpm', '5', 'Y']
# ['43', 'Honda', '2018', '925000', '28900', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'Y']
# ['44', 'Honda', '2013', '425000', '86300', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '16.8', '1497', '116.3', '146Nm@ 4800rpm', '5', 'Y']
# ['45', 'Maruti', '2018', '675000', '23300', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '18.5', '1197', '83.14', '115Nm@ 4000rpm', '5', 'Y']
# ['46', 'Maruti', '2018', '819999', '32600', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['47', 'Maruti', '2018', '390000', '10300', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '23.95', '998', '67.05', '90Nm@ 3500rpm', '5', 'Y']
# ['48', 'Toyota', '2014', '1500000', '77000', 'West', 'Washington', 'Seattle', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '12.55', '2982', '168.5', '343Nm@ 1400-3400rpm', '7', 'Y']
# ['49', 'Toyota', '2013', '700000', '99000', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '12.99', '2494', '100', '200Nm@ 1400-3400rpm', '7', 'Y']
# ['50', 'Mercedes', '2014', '1450000', '27800', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Automatic', 'Second_Owner', '14.8', '2143', '120.7', '200Nm@ 1250-4000rpm', '5', 'Y']
# ['51', 'Honda', '2015', '425000', '49800', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '24.7', '1498', '98.63', '200Nm@ 1750rpm', '5', 'Y']
# ['52', 'Mitsubishi', '2013', '1090000', '151000', 'West', 'Washington', 'Seattle', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '13.5', '2477', '175.56', '400Nm@ 2000-2500rpm', '7', 'Y']
# ['53', 'Honda', '2015', '600000', '54700', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '26', '1498', '98.6', '200Nm@ 1750rpm', '5', 'Y']
# ['54', 'Maruti', '2018', '850000', '64000', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '20.65', '1462', '103.25', '138Nm@ 4400rpm', '5', 'Y']
# ['55', 'Honda', '2015', '525000', '63000', 'South', 'Georgia', 'Atlanta', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '27.3', '1498', '98.6', '200Nm@ 1750rpm', '5', 'Y']
# ['56', 'Toyota', '2016', '1650000', '127700', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Dealer', 'Automatic', 'Second_Owner', '11.36', '2755', '171.5', '360Nm@ 1200-3400rpm', '7', 'Y']
# ['57', 'Toyota', '2016', '950000', '99000', 'South', 'Georgia', 'Atlanta', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '12.99', '2494', '100.6', '200Nm@ 1200-3600rpm', '7', 'Y']
# ['58', 'Audi', '2013', '1750000', '33900', 'South', 'Georgia', 'Atlanta', 'Diesel', 'Dealer', 'Automatic', 'Second_Owner', '17.68', '1968', '174.33', '380Nm@ 1750-2500rpm', '5', 'Y']
# ['59', 'Toyota', '2018', '1590000', '25000', 'South', 'Florida', 'Miami', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.28', '1798', '138.03', '173Nm@ 4000rpm', '5', 'Y']
# ['60', 'Audi', '2013', '1689999', '50000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '18.53', '1968', '187.74', '400Nm@ 1750-3000rpm', '5', 'Y']
# ['61', 'Mercedes', '2013', '1425000', '59000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '14.84', '2143', '170', '400Nm@ 1400-2800rpm', '5', 'Y']
# ['62', 'Tata', '2011', '265000', '120000', 'East', 'Pennsylvania', 'Philadelphia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.12', '1248', '88.8', '200Nm@ 1750-3000rpm', '5', 'Y']
# ['63', 'Hyundai', '2011', '190000', '110000', 'West', 'California', 'San Diego', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '20.36', '1197', '78.9', '111.7Nm@ 4000rpm', '5', 'Y']
# ['64', 'Hyundai', '2013', '425000', '60000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.27', '1396', '88.76', '219.6Nm@ 1500-2750rpm', '5', 'Y']
# ['65', 'Maruti', '2015', '630000', '147000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '26.59', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['66', 'Ford', '2017', '600000', '25000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '18.16', '1196', '86.8', '112Nm@ 4000rpm', '5', 'Y']
# ['67', 'Maruti', '2019', '650000', '30000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.4', '1197', '83.1', '115Nm@ 4000rpm', '5', 'Y']
# ['68', 'Volkswagen', '2016', '540000', '40000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22', '1498', '108.495', '250Nm@ 1500-3000rpm', '5', 'Y']
# ['69', 'Honda', '2015', '630000', '135000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'First_Owner', '25.1', '1498', '98.6', '200Nm@ 1750rpm', '5', 'Y']
# ['70', 'Maruti', '2018', '448000', '30000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '20.51', '998', '67', '90Nm@ 3500rpm', '5', 'Y']
# ['71', 'Volkswagen', '2017', '500000', '80000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.66', '1498', '108.62', '250Nm@ 1500-3000rpm', '5', 'Y']
# ['72', 'Maruti', '2016', '745000', '70000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['73', 'Maruti', '2019', '1025000', '9850', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Automatic', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['74', 'Hyundai', '2011', '235000', '60000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '20.36', '1197', '78.9', '111.7Nm@ 4000rpm', '5', 'Y']
# ['75', 'Maruti', '2016', '630000', '70000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '25.2', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['76', 'Toyota', '2015', '1700000', '78000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '12.55', '2982', '168.5', '343Nm@ 1400-3400rpm', '7', 'Y']
# ['77', 'Maruti', '2013', '450000', '120000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '22.9', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['78', 'Maruti', '2012', '450000', '120000', 'South', 'Florida', 'Miami', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '16.02', '1373', '93.7', '130Nm@ 4000rpm', '7', 'Y']
# ['80', 'Volkswagen', '2013', '450000', '170000', 'South', 'North Carolina', 'Charlotte', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20.54', '1598', '103.6', '250Nm@ 1500-2500rpm', '5', 'Y']
# ['81', 'Toyota', '2016', '1200000', '140000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '12.99', '2494', '100.6', '200Nm@ 1200-3600rpm', '8', 'Y']
# ['82', 'Ford', '2015', '610000', '90000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.77', '1498', '98.59', '205Nm@ 1750-3250rpm', '5', 'Y']
# ['83', 'BMW', '2016', '2500000', '30000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Automatic', 'Second_Owner', '15.71', '1998', '189', '280Nm@ 1350-4600rpm', '5', 'Y']
# ['84', 'Maruti', '2017', '484999', '10000', 'South', 'Florida', 'Miami', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '23.1', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['85', 'Datsun', '2016', '275000', '49000', 'South', 'Florida', 'Miami', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '19.02', '1198', '67.05', '104Nm@ 4000rpm', '5', 'Y']
# ['86', 'Maruti', '2016', '315000', '32000', 'South', 'Florida', 'Miami', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '24.7', '796', '47.3', '69Nm@ 3500rpm', '5', 'Y']
# ['87', 'Maruti', '2016', '275000', '38000', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '24.7', '796', '47.3', '69Nm@ 3500rpm', '5', 'Y']
# ['89', 'Hyundai', '2012', '290000', '28000', 'South', 'Florida', 'Miami', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '19.81', '1086', '68.05', '99.04Nm@ 4500rpm', '5', 'Y']
# ['90', 'Maruti', '2017', '280000', '32000', 'Central', 'Michigan', 'Detroit', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '14', '796', '35', '6.1kgm@ 3000rpm', '5', 'Y']
# ['91', 'Maruti', '2010', '225000', '44000', 'Central', 'Michigan', 'Detroit', 'LPG', 'Dealer', 'Manual', 'First_Owner', '26.2', '998', '58.2', '77Nm@ 3500rpm', '5', 'Y']
# ['92', 'Volkswagen', '2015', '455000', '42000', 'South', 'North Carolina', 'Charlotte', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '16.47', '1198', '74', '110Nm@ 3750rpm', '5', 'Y']
# ['93', 'Hyundai', '2015', '351000', '45000', 'South', 'North Carolina', 'Charlotte', 'Petrol', 'Dealer', 'Manual', 'Second_Owner', '19.81', '1086', '68.05', '99.04Nm@ 4500rpm', '5', 'Y']
# ['94', 'Volkswagen', '2012', '535000', '12000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Dealer', 'Manual', 'Second_Owner', '15.04', '1598', '103.6', '153Nm@ 3800rpm', '5', 'Y']
# ['95', 'Maruti', '2009', '175000', '55500', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '18.2', '998', '67.1', '90Nm@ 3500rpm', '5', 'Y']
# ['96', 'Hyundai', '2013', '525000', '61500', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '18.5', '1197', '82.85', '113.7Nm@ 4000rpm', '5', 'Y']
# ['97', 'Maruti', '2016', '600000', '150000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '26.59', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['98', 'Hyundai', '2016', '565000', '72000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '19.1', '1197', '82', '114Nm@ 4000rpm', '5', 'Y']
# ['99', 'Maruti', '2008', '120000', '68000', 'West', 'California', 'Los Angeles', 'Petrol', 'Dealer', 'Manual', 'Third_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'Y']
# ['100', 'Hyundai', '2017', '725000', '110000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.54', '1396', '88.73', '219.7Nm@ 1500-2750rpm', '5', 'Y']
# ['101', 'Maruti', '2009', '185000', '77000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Dealer', 'Manual', 'Second_Owner', '21.79', '998', '67.05', '90Nm@ 3500rpm', '5', 'Y']
# ['102', 'Tata', '2010', '200000', '100000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '18.8', '1248', '90', '200Nm@ 1750-3000rpm', '5', 'Y']
# ['103', 'Maruti', '2019', '615000', '10000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.21', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['104', 'Maruti', '2016', '270000', '100000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '15.37', '1196', '73', '101Nm@ 3000rpm', '7', 'Y']
# ['105', 'Maruti', '2018', '610000', '35000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.4', '1197', '83.1', '115Nm@ 4000rpm', '5', 'Y']
# ['106', 'Mahindra', '2014', '625000', '70000', 'East', 'Pennsylvania', 'Philadelphia', 'Diesel', 'Individual', 'Automatic', 'Second_Owner', '11.79', '2179', '120', '290Nm@ 1800-2800rpm', '8', 'Y']
# ['107', 'Ford', '2020', '400000', '5000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19', '1194', '94.68', '120Nm@ 4250rpm', '5', 'Y']
# ['108', 'Hyundai', '2017', '866000', '37800', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17', '1591', '121.3', '151Nm@ 4850rpm', '5', 'Y']
# ['109', 'Volkswagen', '2010', '700000', '114000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '14.3', '1798', '160', '250Nm@ 1500~4500rpm', '5', 'Y']
# ['110', 'Tata', '2010', '300000', '48000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'First_Owner', '15.8', '1172', '65', '96 Nm at 3000 rpm', '5', 'Y']
# ['111', 'Mahindra', '2019', '1700000', '32000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '15.1', '2179', '155', '360Nm@ 1750-2800rpm', '7', 'Y']
# ['112', 'Tata', '2016', '375000', '100000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.09', '1405', '69.01', '135Nm@ 2500rpm', '5', 'Y']
# ['113', 'Hyundai', '2013', '522000', '150000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '22.32', '1582', '126.32', '259.8Nm@ 1900-2750rpm', '5', 'Y']
# ['114', 'Hyundai', '2013', '451999', '69000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.9', '1396', '88.76', '219.6Nm@ 1500-2750rpm', '5', 'Y']
# ['115', 'Toyota', '2009', '300000', '100000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '14.53', '1798', '138.1', '173Nm@ 4000rpm', '5', 'Y']
# ['116', 'Maruti', '2020', '475000', '13000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.63', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['117', 'Maruti', '2016', '780000', '60000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['118', 'Maruti', '2017', '595000', '40000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.85', '1197', '83.14', '115Nm@ 4000rpm', '5', 'Y']
# ['119', 'Maruti', '2017', '440000', '35000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.51', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['121', 'Nissan', '2014', '400000', '70000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'Third_Owner', '20.45', '1461', '83.8', '200Nm@ 1900rpm', '5', 'Y']
# ['122', 'Hyundai', '2016', '1140000', '50000', 'East', 'Pennsylvania', 'Philadelphia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.67', '1582', '126.2', '259.9Nm@ 1900-2750rpm', '5', 'Y']
# ['123', 'Ford', '2017', '850000', '76139', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23', '1498', '98.96', '205Nm@ 1750-3250rpm', '5', 'Y']
# ['124', 'Maruti', '2012', '370000', '175000', 'South', 'North Carolina', 'Charlotte', 'Diesel', 'Individual', 'Manual', 'Fourth_Above_Owner', '19.3', '1248', '73.9', '190Nm@ 2000rpm', '5', 'Y']
# ['125', 'Renault', '2018', '350000', '25000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '23.01', '999', '67', '91Nm@ 4250rpm', '5', 'Y']
# ['126', 'Maruti', '2015', '360000', '40000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '23.1', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['127', 'Maruti', '2008', '105000', '65000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'Fourth_Above_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'Y']
# ['128', 'Maruti', '2013', '625000', '90000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '20.77', '1248', '88.76', '200Nm@ 1750rpm', '7', 'Y']
# ['129', 'Hyundai', '2009', '135000', '80000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '17.92', '1086', '62.1', '96.1Nm@ 3000rpm', '5', 'Y']
# ['130', 'Maruti', '2015', '700000', '110000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '20.77', '1248', '88.76', '200Nm@ 1750rpm', '7', 'Y']
# ['131', 'Honda', '2019', '690000', '1303', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1198', '86.7', '109Nm@ 4500rpm', '5', 'Y']
# ['132', 'Audi', '2018', '3975000', '31800', 'West', 'Washington', 'Seattle', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '17.01', '1968', '188', '400nm@ 1750-3000rpm', '5', 'Y']
# ['133', 'Lexus', '2019', '5150000', '20000', 'West', 'Washington', 'Seattle', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '22.37', '2487', '214.56', '202Nm@ 3600-5200rpm', '5', 'Y']
# ['134', 'Jaguar', '2017', '3200000', '45000', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '19.33', '1999', '177', '430Nm@ 1750-2500rpm', '5', 'Y']
# ['135', 'Jeep', '2017', '4100000', '17000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '9.5', '3604', '280', '347Nm@ 4300rpm', '5', 'Y']
# ['136', 'Land', '2019', '4500000', '21000', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '12.83', '1999', '148.31', '382nm@ 1750-2250rpm', '7', 'Y']
# ['137', 'Mercedes', '2017', '6000000', '37000', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '13.5', '2987', '254.79', '620Nm@ 1600-2400rpm', '5', 'Y']
# ['138', 'BMW', '2018', '3790000', '29500', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '22.48', '1995', '187.74', '400Nm@ 1750-2500rpm', '5', 'Y']
# ['140', 'BMW', '2019', '5800000', '7500', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '16.78', '1995', '190', '400Nm@ 1750-2500rpm', '5', 'Y']
# ['141', 'Skoda', '2018', '1864999', '50000', 'West', 'California', 'San Diego', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.67', '1798', '177.46', '250@ 1250-5000rpm', '5', 'Y']
# ['142', 'Mercedes', '2016', '2700000', '35000', 'West', 'California', 'San Diego', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '15', '2143', '204', '500Nm@ 1600-1800rpm', '5', 'Y']
# ['143', 'MG', '2019', '1750000', '19000', 'West', 'California', 'San Diego', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '13.96', '1451', '141', '250Nm@ 1600-3600rpm', '5', 'Y']
# ['144', 'Honda', '2017', '795000', '41000', 'West', 'Washington', 'Seattle', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '18', '1497', '117.6', '145Nm@ 4600rpm', '5', 'Y']
# ['145', 'Toyota', '2013', '625000', '39000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.28', '1798', '138.03', '173Nm@ 4000rpm', '5', 'Y']
# ['146', 'Volvo', '2018', '3400000', '22000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '18', '1969', '190', '400Nm', '5', 'Y']
# ['147', 'Audi', '2015', '2650000', '53000', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '12.07', '2967', '241.4', '550Nm@ 1750-2750rpm', '7', 'Y']
# ['148', 'Maruti', '2015', '535000', '40000', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '26.21', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['149', 'Mercedes', '2017', '5850000', '47000', 'West', 'California', 'Los Angeles', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '13.5', '2987', '282', '490Nm@ 1600rpm', '5', 'Y']
# ['150', 'BMW', '2010', '975000', '72200', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Dealer', 'Automatic', 'Second_Owner', '10.8', '2497', '150', '250 Nm at 2750 rpm', '5', 'Y']
# ['151', 'Hyundai', '2016', '805000', '49900', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '16.3', '1797', '147.5', '177.5Nm@ 4700rpm', '5', 'Y']
# ['152', 'Jaguar', '2017', '2625000', '9000', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '13.6', '1999', '177', '430Nm@ 1750-2500rpm', '5', 'Y']
# ['153', 'Tata', '2018', '811000', '11000', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17', '1198', '108.5', '170Nm@ 1750-4000rpm', '5', 'Y']
# ['154', 'Volkswagen', '2011', '375000', '49000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '15.04', '1598', '103.6', '153Nm@ 3800rpm', '5', 'Y']
# ['155', 'Hyundai', '2012', '550000', '95000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.3', '1797', '147.5', '177.5Nm@ 4700rpm', '5', 'Y']
# ['156', 'Skoda', '2016', '645000', '11000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.3', '1598', '103.5', '153Nm@ 3800rpm', '5', 'Y']
# ['157', 'Mercedes', '2018', '2550000', '18000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '15.04', '1991', '183', '300Nm@ 1200-4000rpm', '5', 'Y']
# ['158', 'Maruti', '2014', '599000', '46100', 'Central', 'Texas', 'Houston', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '16.02', '1373', '93.7', '130Nm@ 4000rpm', '7', 'Y']
# ['159', 'Mercedes', '2017', '2700000', '16000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.74', '1991', '181.04', '300Nm@ 1200-1400rpm', '5', 'Y']
# ['160', 'Honda', '2017', '875000', '18000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '15.6', '1497', '116.3', '146Nm@ 4800rpm', '5', 'Y']
# ['161', 'Toyota', '2019', '894999', '9654', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '19.56', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['162', 'Maruti', '2011', '175000', '11000', 'South', 'North Carolina', 'Charlotte', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '23.95', '998', '67.05', '90Nm@ 3500rpm', '5', 'Y']
# ['163', 'Maruti', '2012', '340000', '24300', 'West', 'Washington', 'Seattle', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '21.21', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['164', 'Toyota', '2016', '1525000', '42163', 'West', 'Washington', 'Seattle', 'Diesel', 'Dealer', 'Automatic', 'Second_Owner', '11.36', '2755', '171.5', '360Nm@ 1200-3400rpm', '7', 'Y']
# ['165', 'Tata', '2018', '1025000', '8000', 'East', 'New York', 'New York City', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '21.5', '1497', '108.5', '260Nm@ 1500-2750rpm', '5', 'Y']
# ['166', 'BMW', '2016', '2150000', '30000', 'South', 'Florida', 'Miami', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '22.69', '1995', '190', '400Nm@ 1750-2500rpm', '5', 'Y']
# ['167', 'Toyota', '2016', '1900000', '41000', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '19.16', '2494', '157.7', '213Nm@ 4500rpm', '5', 'Y']
# ['168', 'BMW', '2016', '2900000', '12000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '18.12', '1995', '190', '400Nm@ 1750-2500rpm', '5', 'Y']
# ['169', 'Toyota', '2009', '450000', '71000', 'East', 'New York', 'New York City', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '12.1', '2362', '164.7', '224Nm@ 4000rpm', '5', 'Y']
# ['170', 'Maruti', '2016', '850000', '20000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.5', '1373', '91.1', '130Nm@ 4000rpm', '7', 'Y']
# ['171', 'Volvo', '2017', '10000000', '30000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '42', '1969', '400', '640Nm@ 1740rpm', '4', 'Y']
# ['172', 'Volkswagen', '2011', '300000', '100000', 'South', 'North Carolina', 'Charlotte', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '20.54', '1598', '103.6', '250Nm@ 1500-2500rpm', '5', 'Y']
# ['173', 'Ford', '2018', '575000', '9500', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.16', '1196', '86.8', '112Nm@ 4000rpm', '5', 'Y']
# ['174', 'Ford', '2011', '160000', '120000', 'Central', 'Texas', 'Houston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20', '1399', '68', '160Nm@ 2000rpm', '5', 'Y']
# ['175', 'Maruti', '2015', '515000', '36600', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.4', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['176', 'Maruti', '2015', '390000', '50000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Automatic', 'Second_Owner', '20.51', '998', '67', '90Nm@ 3500rpm', '5', 'Y']
# ['177', 'Hyundai', '2016', '550000', '14000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.6', '1197', '81.83', '114.7Nm@ 4000rpm', '5', 'Y']
# ['178', 'Maruti', '1999', '40000', '40000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '16.1', '796', '37', '59Nm@ 2500rpm', '4', 'Y']
# ['179', 'Maruti', '2010', '220000', '120000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.1', '1248', '73.9', '113Nm@ 4500rpm', '5', 'Y']
# ['180', 'Hyundai', '2015', '425000', '70000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.9', '1197', '82', '114Nm@ 4000rpm', '5', 'Y']
# ['181', 'Volkswagen', '2019', '480000', '13000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '19.44', '999', '75', '95Nm@ 3000-4300rpm', '5', 'Y']
# ['182', 'Hyundai', '2014', '400000', '60000', 'Central', 'Texas', 'Dallas', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.9', '1197', '82', '114Nm@ 4000rpm', '5', 'Y']
# ['183', 'Maruti', '2014', '487000', '35000', 'South', 'Florida', 'Miami', 'Petrol', 'Individual', 'Manual', 'First_Owner', '19.1', '1197', '85.8', '114Nm@ 4000rpm', '5', 'Y']
# ['184', 'Hyundai', '2016', '386000', '44000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19.1', '1197', '82', '114Nm@ 4000rpm', '5', 'Y']
# ['185', 'Honda', '2005', '100000', '120000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '13', '1493', '100', '13.1kgm@ 4600rpm', '5', 'Y']
# ['186', 'Toyota', '2010', '300000', '60000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '21.43', '1364', '87.2', '205Nm@ 1800-2800rpm', '5', 'Y']
# ['187', 'Daewoo', '2000', '100000', '60000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.5', '796', '53', '71Nm@ 3500rpm', '5', 'Y']
# ['188', 'Toyota', '2014', '1750000', '30000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '13', '2982', '168.5', '343Nm@ 1400-3400rpm', '7', 'Y']
# ['189', 'Mahindra', '2016', '450000', '15000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.15', '1198', '82', '115Nm@ 3500-3600rpm', '6', 'Y']
# ['190', 'Tata', '2017', '490000', '90000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.95', '1248', '74', '190Nm@ 1750-3000rpm', '5', 'Y']
# ['191', 'Honda', '2009', '345000', '47000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '17', '1497', '118', '146Nm at 4800 rpm', '5', 'Y']
# ['192', 'Maruti', '2005', '85000', '90000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.3', '993', '60', '78Nm@ 4500rpm', '5', 'Y']
# ['193', 'Maruti', '2010', '215000', '120600', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.9', '998', '67.1', '90Nm@ 3500rpm', '5', 'Y']
# ['194', 'Hyundai', '2010', '320000', '100000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '16.2', '1599', '103.2', '14.9 KGM at 3000 RPM', '5', 'Y']
# ['195', 'Maruti', '2016', '459999', '60000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '20.85', '1197', '83.14', '115Nm@ 4000rpm', '5', 'Y']
# ['196', 'Hyundai', '2005', '65000', '86000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '15.3', '1341', '83', '115Nm@ 3200rpm', '5', 'Y']
# ['197', 'Hyundai', '2020', '720000', '5000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.6', '1197', '81.86', '117nm@ 4000rpm', '5', 'Y']
# ['198', 'Maruti', '2017', '800000', '37000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '28.09', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['199', 'Tata', '2019', '520000', '14000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.3', '1199', '84', '114Nm@ 3500rpm', '5', 'Y']
# ['200', 'Maruti', '2015', '580000', '70000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20.77', '1248', '88.76', '200Nm@ 1750rpm', '7', 'Y']
# ['202', 'Honda', '2015', '600000', '50000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.4', '1497', '117.3', '145Nm@ 4600rpm', '5', 'Y']
# ['203', 'Honda', '2014', '290000', '60000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19.4', '1198', '86.8', '109Nm@ 4500rpm', '5', 'Y']
# ['204', 'Maruti', '2016', '360000', '50000', 'Central', 'Illinois', 'Chicago', 'CNG', 'Individual', 'Manual', 'First_Owner', '26.6', '998', '58.16', '77Nm@ 3500rpm', '5', 'Y']
# ['205', 'Maruti', '2017', '550000', '50000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.85', '1197', '83.14', '115Nm@ 4000rpm', '5', 'Y']
# ['206', 'Hyundai', '2013', '375000', '70000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.5', '1197', '82.85', '113.7Nm@ 4000rpm', '5', 'Y']
# ['208', 'Maruti', '2018', '420000', '35000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '20.51', '998', '67', '90Nm@ 3500rpm', '5', 'Y']
# ['209', 'Maruti', '2017', '550000', '20000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '21.21', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['210', 'Maruti', '2018', '270000', '20000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '24.7', '796', '47.3', '69Nm@ 3500rpm', '5', 'Y']
# ['211', 'Maruti', '2018', '700000', '7800', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '22', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['212', 'Maruti', '2017', '500000', '20000', 'Central', 'Illinois', 'Chicago', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.4', '1197', '81.8', '113Nm@ 4200rpm', '5', 'Y']
# ['213', 'Tata', '2019', '1250000', '15000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'First_Owner', '17.6', '2179', '147.94', '320Nm@ 1500-3000rpm', '7', 'Y']
# ['214', 'Hyundai', '2013', '320000', '31377', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.5', '1197', '82.85', '113.7Nm@ 4000rpm', '5', 'Y']
# ['215', 'Maruti', '2018', '700000', '50000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '28.4', '1248', '74.02', '190Nm@ 2000rpm', '5', 'Y']
# ['216', 'Maruti', '2015', '290000', '60000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.51', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['217', 'Toyota', '2012', '550000', '100000', 'Central', 'Michigan', 'Detroit', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '14.53', '1794', '138.1', '173Nm@ 4000rpm', '5', 'Y']
# ['218', 'Honda', '2012', '265000', '60000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '19.4', '1198', '86.8', '109Nm@ 4500rpm', '5', 'Y']
# ['219', 'Maruti', '2018', '830000', '5000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '21.4', '1197', '83.1', '115Nm@ 4000rpm', '5', 'Y']
# ['220', 'Tata', '2017', '800000', '60000', 'South', 'Georgia', 'Atlanta', 'Diesel', 'Individual', 'Manual', 'First_Owner', '14.1', '2179', '147.94', '320Nm@ 1500-3000rpm', '7', 'Y']
# ['221', 'Maruti', '2011', '160000', '25000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'Y']
# ['222', 'Renault', '2018', '335000', '30000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '25.17', '799', '53.3', '72Nm@ 4386rpm', '5', 'Y']
# ['223', 'Datsun', '2017', '329000', '80000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '20.63', '1198', '67', '104Nm@ 4000rpm', '5', 'Y']
# ['224', 'Maruti', '2017', '775000', '75000', 'East', 'Pennsylvania', 'Philadelphia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.3', '1248', '88.5', '200Nm@ 1750rpm', '5', 'Y']
# ['225', 'Hyundai', '2020', '524000', '32000', 'South', 'Georgia', 'Atlanta', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.14', '1197', '81.86', '113.75nm@ 4000rpm', '5', 'Y']
# ['226', 'Maruti', '2015', '245000', '40000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '22.74', '796', '47.3', '69Nm@ 3500rpm', '5', 'Y']
# ['227', 'Hyundai', '2012', '275000', '93000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '17', '1197', '80', '11.4 kgm at 4,000 rpm', '5', 'Y']
# ['228', 'Tata', '2018', '520000', '60000', 'West', 'Washington', 'Seattle', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.57', '1193', '88.7', '140Nm@ 1500-4000rpm', '5', 'Y']
# ['230', 'Nissan', '2014', '550000', '37000', 'Central', 'Michigan', 'Detroit', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.95', '1498', '97.7', '134Nm@ 4000rpm', '5', 'Y']
# ['231', 'Ford', '2018', '910000', '15000', 'Central', 'Michigan', 'Detroit', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17', '1497', '121.36', '150Nm@ 4500rpm', '5', 'Y']
# ['232', 'Nissan', '2015', '300000', '80000', 'Central', 'Michigan', 'Detroit', 'Petrol', 'Individual', 'Manual', 'First_Owner', '19.49', '1198', '67.04', '104Nm@ 4000rpm', '5', 'Y']
# ['233', 'Maruti', '2016', '350000', '140000', 'East', 'Massachusetts', 'Boston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.51', '998', '67.04', '90Nm@ 3500rpm', '5', 'Y']
# ['234', 'Mahindra', '2013', '900000', '70000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '12.83', '2696', '162', '340Nm@ 1800-3250rpm', '7', 'Y']
# ['235', 'Mahindra', '2013', '300000', '120000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '17.21', '1493', '100', '240Nm@ 1600-2800rpm', '7', 'Y']
# ['236', 'Maruti', '2010', '250000', '110000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '21.1', '1248', '73.9', '190Nm@ 2000rpm', '5', 'Y']
# ['237', 'Hyundai', '2017', '1100000', '37000', 'Central', 'Michigan', 'Detroit', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.67', '1582', '126.2', '259.9Nm@ 1900-2750rpm', '5', 'Y']
# ['238', 'Renault', '2016', '270000', '44000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '25.17', '799', '53.3', '72Nm@ 4386rpm', '5', 'Y']
# ['239', 'Maruti', '2015', '640000', '80000', 'East', 'District of Columbia', 'Washington', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20.77', '1248', '88.76', '200Nm@ 1750rpm', '7', 'Y']
# ['240', 'Mahindra', '2015', '650000', '125000', 'Central', 'Illinois', 'Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '15.1', '2179', '140', '330Nm@ 1600-2800rpm', '7', 'Y']
# ['241', 'Maruti', '2017', '409999', '13500', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '15.37', '1196', '73', '101Nm@ 3000rpm', '5', 'Y']
# ['242', 'Hyundai', '2011', '165000', '75000', 'East', 'District of Columbia', 'Washington', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.92', '1086', '62.1', '96.1Nm@ 3000rpm', '5', 'Y']
# ['243', 'Hyundai', '2007', '80000', '120000', 'East', 'Pennsylvania', 'Philadelphia', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '13.2', '1495', '94', '12.5@ 3,500(kgm@ rpm)', '5', 'Y']
# ['244', 'Mahindra', '2012', '535000', '120000', 'East', 'Pennsylvania', 'Philadelphia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '15.1', '2179', '140', '330Nm@ 1600-2800rpm', '7', 'Y']
# ['245', 'Toyota', '2013', '700000', '70000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '12.99', '2494', '100.57', '200Nm@ 1400-3400rpm', '7', 'Y']
# ['246', 'Maruti', '2013', '550000', '70000', 'East', 'New York', 'New York City', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.4', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['247', 'Honda', '2019', '680000', '15000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '19', '1199', '88.76', '110Nm@ 4800rpm', '5', 'Y']
# ['248', 'Hyundai', '2009', '200000', '53000', 'West', 'California', 'Los Angeles', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '20.36', '1197', '78.9', '111.8Nm@ 4000rpm', '5', 'Y']
# ['249', 'Maruti', '2014', '500000', '120000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '23.4', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['250', 'Maruti', '2016', '1000000', '70000', 'Central', 'Texas', 'Dallas', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.52', '1248', '88.5', '200Nm@ 1750rpm', '7', 'Y']
# ['251', 'Hyundai', '2008', '110000', '120000', 'West', 'California', 'San Diego', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '14.2', '1341', '82.9', '11.8@ 3,200(kgm@ rpm)', '5', 'Y']
# ['252', 'Hyundai', '2012', '320000', '100000', 'West', 'California', 'San Diego', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.5', '1197', '80', '11.4 kgm at 4,000 rpm', '5', 'Y']
# ['254', 'Maruti', '2015', '350000', '100000', 'East', 'New York', 'New York City', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.4', '1197', '83.11', '113Nm@ 4200rpm', '5', 'Y']
# ['255', 'Tata', '2013', '170000', '162500', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.4', '1405', '70', '135.4Nm@ 2500rpm', '5', 'Y']
# ['256', 'Hyundai', '2017', '800000', '39000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.54', '1396', '88.73', '219.7Nm@ 1500-2750rpm', '5', 'Y']
# ['257', 'Maruti', '2017', '500000', '75000', 'East', 'Massachusetts', 'Boston', 'Diesel', 'Individual', 'Manual', 'First_Owner', '26.8', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['258', 'Tata', '2017', '1380000', '50000', 'South', 'Florida', 'Miami', 'Diesel', 'Individual', 'Automatic', 'First_Owner', '17.6', '2179', '153.86', '400Nm@ 1750-2500rpm', '7', 'Y']
# ['259', 'Mahindra', '2019', '1300000', '40000', 'South', 'Florida', 'Miami', 'Diesel', 'Individual', 'Manual', 'First_Owner', '17.3', '1497', '121', '300Nm@ 1750-2500rpm', '8', 'Y']
# ['260', 'Hyundai', '2013', '530000', '92500', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.32', '1582', '126.3', '259.9Nm@ 1900-2750rpm', '5', 'Y']
# ['261', 'Maruti', '2012', '360000', '158000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.4', '1248', '74', '190Nm@ 2000rpm', '5', 'Y']
# ['262', 'Maruti', '2012', '310000', '120000', 'West', 'California', 'Los Angeles', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.3', '1248', '73.9', '190Nm@ 2000rpm', '5', 'Y']
# ['263', 'Honda', '2015', '725000', '50000', 'West', 'Washington', 'Seattle', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '26', '1498', '98.6', '200Nm@ 1750rpm', '5', 'Y']
# ['264', 'Maruti', '2012', '340000', '110000', 'Central', 'Michigan', 'Detroit', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.3', '1248', '73.9', '190Nm@ 2000rpm', '5', 'Y']
# ['265', 'Hyundai', '2017', '550000', '2000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '25.4', '1186', '73.97', '190.25nm@ 1750-2250rpm', '5', 'Y']
# ['266', 'Toyota', '2011', '1150000', '181000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '11.5', '2982', '171', '343Nm@ 1400-3400rpm', '7', 'Y']
# ['267', 'Tata', '2016', '380000', '70000', 'West', 'California', 'San Francisco', 'Diesel', 'Individual', 'Manual', 'First_Owner', '27.28', '1047', '69', '140Nm@ 1800-3000rpm', '5', 'Y']
# ['268', 'Nissan', '2013', '350000', '90000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Automatic', 'Second_Owner', '17.97', '1498', '99.6', '134Nm@ 4000rpm', '5', 'Y']
# ['269', 'Hyundai', '2019', '610000', '2000', 'Central', 'Texas', 'Houston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.6', '1197', '81.86', '117nm@ 4000rpm', '5', 'Y']
# ['270', 'Maruti', '2015', '525000', '20000', 'West', 'California', 'San Diego', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.85', '1197', '83.14', '115Nm@ 4000rpm', '5', 'Y']
# ...
# ['8040', 'Maruti', '2011', '135000', '110048', 'East', 'Ohio', 'Lancaster', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '20.92', '998', '67.1', '90Nm@ 3500rpm', '5', 'N']
# ['8041', 'Hyundai', '2018', '680000', '26000', 'East', 'Ohio', 'Kettering', 'Diesel', 'Individual', 'Manual', 'First_Owner', '25.4', '1186', '73.97', '190.24nm@ 1750-2250rpm', '5', 'N']
# ['8042', 'Maruti', '2007', '90000', '110000', 'East', 'Ohio', 'Lima', 'Petrol', 'Individual', 'Manual', 'Fourth_Above_Owner', '18.9', '1061', '67', '84Nm@ 3500rpm', '5', 'N']
# ['8043', 'Maruti', '1997', '300000', '186388', 'East', 'Ohio', 'Lima', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '14.8', '1298', '80', '103Nm@ 4500rpm', '8', 'N']
# ['8044', 'Chevrolet', '2007', '100000', '60000', 'East', 'New York', 'Kenmore', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '14.7', '1150', '76', '11.2@ 4,400(kgm@ rpm)', '5', 'N']
# ['8045', 'Maruti', '2006', '120000', '70000', 'East', 'Ohio', 'Lancaster', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'N']
# ['8046', 'Renault', '2017', '750000', '20171', 'East', 'Ohio', 'Lancaster', 'Diesel', 'Dealer', 'Automatic', 'First_Owner', '19.87', '1461', '108.5', '245Nm@ 1750rpm', '5', 'N']
# ['8047', 'Honda', '2017', '525000', '37151', 'East', 'Ohio', 'Lima', 'Diesel', 'Dealer', 'Manual', 'First_Owner', '27.3', '1498', '98.6', '200Nm@ 1750rpm', '5', 'N']
# ['8048', 'Honda', '2015', '649000', '39000', 'East', 'Ohio', 'Lancaster', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.4', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8049', 'Volkswagen', '2010', '210000', '44500', 'East', 'New York', 'Kenmore', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '16.47', '1198', '74', '110Nm@ 3750rpm', '5', 'N']
# ['8050', 'Honda', '2016', '526000', '15000', 'East', 'New York', 'Kenmore', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '18.7', '1199', '88.7', '110Nm@ 4800rpm', '5', 'N']
# ['8051', 'Ford', '2016', '599000', '39000', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '15.9', '1496', '120.69', '149Nm@ 4500rpm', '5', 'N']
# ['8052', 'Honda', '2015', '500000', '58161', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8053', 'Honda', '2012', '750000', '50171', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '11.1', '2354', '158.8', '218Nm@ 4200rpm', '5', 'N']
# ['8054', 'Honda', '2011', '325000', '40000', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.4', '1497', '117.6', '145Nm@ 4600rpm', '5', 'N']
# ['8055', 'Honda', '2016', '575000', '55161', 'East', 'Pennsylvania', 'Bethel Park', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8056', 'Honda', '2012', '245000', '30000', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '18.5', '1198', '86.8', '109Nm@ 4500rpm', '5', 'N']
# ['8057', 'Honda', '2016', '625000', '55000', 'South', 'Florida', 'Belle Glade', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8058', 'Honda', '2013', '580000', '50000', 'East', 'Pennsylvania', 'Bethel Park', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '11.7', '2354', '177.6', '222Nm@ 4300rpm', '5', 'N']
# ['8059', 'Audi', '2017', '1689999', '8000', 'South', 'Arkansas', 'Van Buren', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '16.6', '1798', '177.5', '250Nm@ 1250-5000rpm', '5', 'N']
# ['8060', 'Hyundai', '2018', '1175000', '14000', 'South', 'Arkansas', 'Van Buren', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '15.8', '1591', '121.3', '151Nm@ 4850rpm', '5', 'N']
# ['8061', 'Honda', '2015', '575000', '9599', 'South', 'Arkansas', 'Van Buren', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8062', 'Hyundai', '2017', '600000', '35000', 'West', 'Washington', 'Seatac', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17', '1197', '80', '11.4 kgm at 4,000 rpm', '5', 'N']
# ['8063', 'Honda', '2016', '750000', '16151', 'Central', 'Texas', 'Saginaw', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8064', 'Hyundai', '2016', '890000', '40000', 'Central', 'Texas', 'Saginaw', 'Petrol', 'Dealer', 'Automatic', 'First_Owner', '14.8', '1591', '121.3', '151NM@ 4850rpm', '5', 'N']
# ['8065', 'Honda', '2015', '600000', '28161', 'West', 'Washington', 'Seatac', 'Petrol', 'Dealer', 'Manual', 'First_Owner', '17.8', '1497', '117.3', '145Nm@ 4600rpm', '5', 'N']
# ['8066', 'Chevrolet', '2010', '114999', '60000', 'West', 'Idaho', 'Moscow', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18', '995', '62', '90.3Nm@ 4200rpm', '5', 'N']
# ['8067', 'Chevrolet', '2010', '140000', '60000', 'West', 'Idaho', 'Moscow', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18', '995', '62', '90.3Nm@ 4200rpm', '5', 'N']
# ['8068', 'Mahindra', '2011', '360000', '100000', 'West', 'New Mexico', 'Alamogordo', 'Diesel', 'Individual', 'Manual', 'Fourth_Above_Owner', '13.5', '2179', '115', '277.5Nm@ 1700-2200rpm', '5', 'N']
# ['8070', 'Maruti', '2017', '500000', '130000', 'Central', 'Michigan', 'Walker', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '19', '1197', '85.8', '114Nm@ 4000rpm', '5', 'N']
# ['8071', 'Honda', '2015', '409999', '60000', 'West', 'New Mexico', 'Alamogordo', 'Diesel', 'Individual', 'Manual', 'First_Owner', '25.8', '1498', '98.6', '200Nm@ 1750rpm', '5', 'N']
# ['8072', 'Toyota', '2010', '425000', '200000', 'West', 'New Mexico', 'Alamogordo', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '12.8', '2494', '102', '20.4@ 1400-3400(kgm@ rpm)', '7', 'N']
# ['8073', 'Nissan', '2014', '450000', '82000', 'West', 'Idaho', 'Moscow', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '20.45', '1461', '83.8', '200Nm@ 1900rpm', '5', 'N']
# ['8074', 'Hyundai', '2014', '400000', '20000', 'West', 'Idaho', 'Moscow', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.9', '1197', '82', '114Nm@ 4000rpm', '5', 'N']
# ['8075', 'Maruti', '2013', '295000', '60000', 'West', 'Idaho', 'Moscow', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '16.51', '1586', '103.2', '145Nm@ 4100rpm', '5', 'N']
# ['8076', 'Maruti', '2014', '560000', '90000', 'West', 'Idaho', 'Moscow', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '26.21', '1248', '88.5', '200Nm@ 1750rpm', '5', 'N']
# ['8077', 'Maruti', '2006', '150000', '50000', 'West', 'Idaho', 'Moscow', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '14', '1061', '64', '8.6@ 3,500(kgm@ rpm)', '5', 'N']
# ['8078', 'Toyota', '2009', '550000', '250000', 'West', 'New Mexico', 'Alamogordo', 'Diesel', 'Individual', 'Manual', 'First_Owner', '12.8', '2494', '102', '20.4@ 1400-3400(kgm@ rpm)', '7', 'N']
# ['8079', 'Chevrolet', '2011', '114999', '100000', 'Central', 'Texas', 'Sulphur Springs', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18', '995', '62', '90.3Nm@ 4200rpm', '5', 'N']
# ['8080', 'Tata', '2007', '90177', '129000', 'Central', 'Texas', 'Sulphur Springs', 'Diesel', 'Individual', 'Manual', 'Third_Owner', '17', '1405', '70', '13.5@ 2,500(kgm@ rpm)', '5', 'N']
# ['8081', 'Tata', '2010', '300000', '100000', 'West', 'Washington', 'Yakima', 'Diesel', 'Individual', 'Manual', 'First_Owner', '11.57', '2179', '138.1', '320Nm@ 1700-2700rpm', '7', 'N']
# ['8082', 'Honda', '2005', '110000', '100000', 'West', 'Wyoming', 'Casper', 'Petrol', 'Individual', 'Automatic', 'Second_Owner', '12', '1493', '100', '13.1kgm@ 4600rpm', '5', 'N']
# ['8083', 'Ford', '2007', '125000', '110000', 'West', 'Washington', 'Yakima', 'Diesel', 'Individual', 'Manual', 'Third_Owner', '17.8', '1399', '68', '16.3@ 2,000(kgm@ rpm)', '5', 'N']
# ['8084', 'Chevrolet', '2008', '300000', '100000', 'West', 'Wyoming', 'Casper', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '11.5', '1991', '147.9', '320Nm@ 2000rpm', '7', 'N']
# ['8085', 'Hyundai', '2017', '450000', '20000', 'West', 'Wyoming', 'Casper', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.9', '1197', '81.86', '113.75nm@ 4000rpm', '5', 'N']
# ['8086', 'Chevrolet', '2011', '300000', '40000', 'West', 'Wyoming', 'Casper', 'Diesel', 'Individual', 'Manual', 'First_Owner', '18.3', '1991', '147.9', '327Nm@ 2600rpm', '5', 'N']
# ['8087', 'Maruti', '2018', '470000', '30000', 'West', 'Wyoming', 'Casper', 'Petrol', 'Individual', 'Automatic', 'First_Owner', '23.1', '998', '67.04', '90Nm@ 3500rpm', '5', 'N']
# ['8088', 'Tata', '2015', '330000', '25000', 'East', 'West Virginia', 'Charleston', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.57', '1193', '88.7', '140Nm@ 1500-4000rpm', '5', 'N']
# ['8089', 'Maruti', '2018', '390000', '25000', 'Central', 'Texas', 'Sulphur Springs', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '20.51', '998', '67.04', '90Nm@ 3500rpm', '5', 'N']
# ['8090', 'Tata', '2011', '46000', '25000', 'West', 'Washington', 'Yakima', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '26', '624', '35', '48Nm@ 3000rpm', '4', 'N']
# ['8091', 'Nissan', '2013', '509999', '170000', 'South', 'Virginia', 'Tysons Corner', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20.45', '1461', '83.8', '200Nm@ 1900rpm', '5', 'N']
# ['8092', 'Fiat', '2010', '125000', '40000', 'West', 'California', 'Visalia', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '16', '1368', '90', '115Nm@ 4500rpm', '5', 'N']
# ['8093', 'Hyundai', '2017', '780000', '28000', 'West', 'California', 'Visalia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.54', '1396', '88.73', '219.7Nm@ 1500-2750rpm', '5', 'N']
# ['8094', 'Hyundai', '2011', '450000', '100000', 'West', 'California', 'Visalia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '22.32', '1582', '126.3', '259.9Nm@ 1900-2750rpm', '5', 'N']
# ['8095', 'Tata', '2012', '200000', '80868', 'West', 'California', 'Visalia', 'Petrol', 'Individual', 'Manual', 'Third_Owner', '13.7', '1368', '88.8', '116Nm@ 4750rpm', '5', 'N']
# ['8096', 'Ford', '2012', '260000', '194000', 'West', 'California', 'Visalia', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20', '1399', '68', '160Nm@ 2000rpm', '5', 'N']
# ['8097', 'Maruti', '2009', '250000', '151000', 'South', 'Virginia', 'Tysons Corner', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '17.8', '1248', '75', '190Nm@ 2000rpm', '5', 'N']
# ['8098', 'Ford', '2018', '880000', '65000', 'Central', 'Indiana', 'East Chicago', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23', '1498', '98.96', '205Nm@ 1750-3250rpm', '5', 'N']
# ['8099', 'Maruti', '2009', '307000', '100000', 'Central', 'Indiana', 'East Chicago', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '17.8', '1248', '75', '190Nm@ 2000rpm', '5', 'N']
# ['8100', 'Mahindra', '2013', '750000', '120000', 'Central', 'Indiana', 'Elkhart', 'Diesel', 'Individual', 'Manual', 'First_Owner', '15.1', '2179', '140', '330Nm@ 1600-2800rpm', '7', 'N']
# ['8101', 'Tata', '2018', '800000', '85000', 'Central', 'Indiana', 'Elkhart', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '21.5', '1497', '108.5', '260Nm@ 1500-2750rpm', '5', 'N']
# ['8102', 'Fiat', '2012', '450000', '70000', 'Central', 'Indiana', 'Elkhart', 'Diesel', 'Individual', 'Manual', 'First_Owner', '20.3', '1248', '75', '197Nm@ 1750rpm', '5', 'N']
# ['8103', 'Hyundai', '2011', '450000', '128000', 'Central', 'Indiana', 'Elkhart', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '22.32', '1582', '126.32', '259.8Nm@ 1900-2750rpm', '5', 'N']
# ['8105', 'Honda', '2006', '160000', '70000', 'West', 'California', 'Laguna Hills', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '16.9', '1497', '100', '13.5@ 4,800(kgm@ rpm)', '5', 'N']
# ['8106', 'Honda', '2004', '135000', '120000', 'West', 'California', 'Laguna Hills', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '13', '1343', '90', '11.3kgm@ 4700rpm', '5', 'N']
# ['8107', 'Hyundai', '2012', '450000', '128000', 'West', 'California', 'Laguna Hills', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '22.32', '1582', '126.32', '259.8Nm@ 1900-2750rpm', '5', 'N']
# ['8108', 'Renault', '2013', '325000', '100000', 'West', 'California', 'Laguna Hills', 'Diesel', 'Individual', 'Manual', 'Third_Owner', '20.45', '1461', '83.8', '200Nm@ 1900rpm', '5', 'N']
# ['8109', 'Kia', '2019', '1575000', '20000', 'West', 'California', 'Laguna Hills', 'Diesel', 'Individual', 'Automatic', 'First_Owner', '17.8', '1493', '113.4', '250nm@ 1500-2750rpm', '5', 'N']
# ['8110', 'Ford', '2018', '750000', '24000', 'West', 'California', 'Laguna Hills', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.4', '1498', '98.63', '215Nm@ 1750-3000rpm', '5', 'N']
# ['8111', 'Maruti', '2017', '425000', '12000', 'South', 'North Carolina', 'New Bern', 'Petrol', 'Individual', 'Manual', 'First_Owner', '23.1', '998', '67.04', '90Nm@ 3500rpm', '5', 'N']
# ['8112', 'Toyota', '2014', '425000', '50000', 'South', 'North Carolina', 'New Bern', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.59', '1364', '67.06', '170Nm@ 1800-2400rpm', '5', 'N']
# ['8113', 'Ford', '2018', '746000', '24000', 'South', 'North Carolina', 'Mooresville', 'Diesel', 'Individual', 'Manual', 'First_Owner', '24.4', '1498', '98.63', '215Nm@ 1750-3000rpm', '5', 'N']
# ['8114', 'Toyota', '2010', '425000', '129000', 'South', 'North Carolina', 'Mooresville', 'Diesel', 'Individual', 'Manual', 'First_Owner', '12.8', '2494', '102', '20.4@ 1400-3400(kgm@ rpm)', '8', 'N']
# ['8115', 'Maruti', '2011', '200000', '73000', 'South', 'North Carolina', 'Mooresville', 'Petrol', 'Individual', 'Manual', 'First_Owner', '19.7', '796', '46.3', '62Nm@ 3000rpm', '5', 'N']
# ['8116', 'Maruti', '1997', '40000', '120000', 'South', 'North Carolina', 'Mooresville', 'Petrol', 'Individual', 'Manual', 'First_Owner', '16.1', '796', '37', '59Nm@ 2500rpm', '4', 'N']
# ['8117', 'Maruti', '2017', '340000', '45000', 'South', 'North Carolina', 'Mooresville', 'Petrol', 'Individual', 'Manual', 'First_Owner', '23.95', '998', '67.1', '90Nm@ 3500rpm', '5', 'N']
# ['8118', 'Maruti', '2015', '625000', '50000', 'South', 'North Carolina', 'Monroe', 'Diesel', 'Individual', 'Manual', 'First_Owner', '26.59', '1248', '74', '190Nm@ 2000rpm', '5', 'N']
# ['8119', 'Hyundai', '2013', '380000', '25000', 'South', 'North Carolina', 'Mooresville', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.5', '1197', '82.85', '113.7Nm@ 4000rpm', '5', 'N']
# ['8120', 'Maruti', '2017', '360000', '80000', 'South', 'North Carolina', 'Monroe', 'Petrol', 'Individual', 'Manual', 'First_Owner', '20.51', '998', '67.04', '90Nm@ 3500rpm', '5', 'N']
# ['8121', 'Hyundai', '2008', '120000', '191000', 'South', 'North Carolina', 'Mooresville', 'Petrol', 'Individual', 'Manual', 'First_Owner', '17.92', '1086', '62.1', '96.1Nm@ 3000rpm', '5', 'N']
# ['8122', 'Maruti', '2013', '260000', '50000', 'Central', 'Texas', 'Plano', 'Petrol', 'Individual', 'Manual', 'Second_Owner', '18.9', '998', '67.1', '90Nm@ 3500rpm', '5', 'N']
# ['8123', 'Hyundai', '2014', '475000', '80000', 'Central', 'Texas', 'Plano', 'Diesel', 'Individual', 'Manual', 'Second_Owner', '22.54', '1396', '88.73', '219.7Nm@ 1500-2750rpm', '5', 'N']
# ['8124', 'Hyundai', '2013', '320000', '110000', 'Central', 'Texas', 'Plano', 'Petrol', 'Individual', 'Manual', 'First_Owner', '18.5', '1197', '82.85', '113.7Nm@ 4000rpm', '5', 'N']
# ['8125', 'Hyundai', '2007', '135000', '119000', 'Central', 'Texas', 'Port Arthur', 'Diesel', 'Individual', 'Manual', 'Fourth_Above_Owner', '16.8', '1493', '110', '24@ 1,900-2,750(kgm@ rpm)', '5', 'N']
# ['8126', 'Maruti', '2009', '382000', '120000', 'Central', 'Texas', 'Port Arthur', 'Diesel', 'Individual', 'Manual', 'First_Owner', '19.3', '1248', '73.9', '190Nm@ 2000rpm', '5', 'N']
# ['8127', 'Tata', '2013', '290000', '25000', 'East', 'Massachusetts', 'Lunenburg', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.57', '1396', '70', '140Nm@ 1800-3000rpm', '5', 'N']
# ['8128', 'Tata', '2013', '290000', '25000', 'East', 'Maine', 'Augusta', 'Diesel', 'Individual', 'Manual', 'First_Owner', '23.57', '1396', '70', '140Nm@ 1800-3000rpm', '5', 'N']

# %%
import pandas as pd

# File paths
input_file = 'UserCarData.csv'
output_file = 'cleanCSVData.csv'

try:
    # Load the data
    df = pd.read_csv(input_file)
    print("Initial columns:", df.columns.tolist())
    print("raw data shape:", df.shape)

    # Remove duplicates
    df.drop_duplicates(inplace=True)

    # Drop rows with any missing values
    df.dropna(inplace=True)

    # Standardize column names
    df.columns = [col.strip().replace(" ", "_").lower() for col in df.columns]

    # Rename selling_price to price for easier reference
    if 'selling_price' in df.columns:
        df.rename(columns={'selling_price': 'price'}, inplace=True)

    # Normalize column types
    for col in ['year', 'mileage', 'price']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Drop rows where conversion introduced NaNs
    df.dropna(subset=['year', 'mileage', 'price'], inplace=True)

    # Filter out unrealistic or invalid data
    df = df[(df['year'] <= 2025) & (df['mileage'] > 0)]

    print("Cleaned data shape:", df.shape)

    # Save to new CSV
    df.to_csv(output_file, index=False)
    print(f"✅ Cleaned data saved to: {output_file}")

except FileNotFoundError:
    print(f"❌ File not found: {input_file}")
except pd.errors.ParserError:
    print("❌ Error while parsing the CSV file.")
except Exception as e:
    print(f"❌ An unexpected error occurred: {e}")
# Out:
# Initial columns: ['Sales_ID', 'name', 'year', 'selling_price', 'km_driven', 'Region', 'State or Province', 'City', 'fuel', 'seller_type', 'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats', 'sold']
# raw data shape: (7906, 18)
# Cleaned data shape: (7889, 18)
# ✅ Cleaned data saved to: cleanCSVData.csv

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.2.0-cp313-cp313-win_amd64.whl.metadata (6.2 kB)
# Downloading mysql_connector_python-9.2.0-cp313-cp313-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.1 MB 1.8 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/16.1 MB 1.8 MB/s eta 0:00:09
#    --- ------------------------------------ 1.3/16.1 MB 1.7 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.8/16.1 MB 1.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/16.1 MB 2.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.4/16.1 MB 1.8 MB/s eta 0:00:08
#    ------- -------------------------------- 3.1/16.1 MB 2.0 MB/s eta 0:00:07
#    -------- ------------------------------- 3.4/16.1 MB 2.0 MB/s eta 0:00:07
#    --------- ------------------------------ 3.9/16.1 MB 2.0 MB/s eta 0:00:07
#    ----------- ---------------------------- 4.5/16.1 MB 2.1 MB/s eta 0:00:06
#    ------------ --------------------------- 5.0/16.1 MB 2.1 MB/s eta 0:00:06
#    ------------- -------------------------- 5.5/16.1 MB 2.1 MB/s eta 0:00:05
#    -------------- ------------------------- 5.8/16.1 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.6/16.1 MB 2.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 7.1/16.1 MB 2.2 MB/s eta 0:00:05
#    ------------------- -------------------- 7.9/16.1 MB 2.3 MB/s eta 0:00:04
#    -------------------- ------------------- 8.1/16.1 MB 2.2 MB/s eta 0:00:04
#    --------------------- ------------------ 8.7/16.1 MB 2.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 9.2/16.1 MB 2.3 MB/s eta 0:00:04
#    ------------------------ --------------- 9.7/16.1 MB 2.3 MB/s eta 0:00:03
#    ------------------------- -------------- 10.2/16.1 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 10.7/16.1 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.3/16.1 MB 2.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.5/16.1 MB 2.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 12.1/16.1 MB 2.3 MB/s eta 0:00:02
#    ------------------------------- -------- 12.6/16.1 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 13.1/16.1 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 13.6/16.1 MB 2.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.9/16.1 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.4/16.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/16.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# MySQL credentials
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='root',
    database='UsedCarsDB'
)

cursor = conn.cursor()

# %%
import pandas as pd
import mysql.connector

# Load cleaned data
df = pd.read_csv('cleanCSVData.csv')

# Connect to MySQL
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='root',
    database='UsedCarsDB'
)
cursor = conn.cursor()
#cursor.execute("DROP TABLE IF EXISTS used_cars")

# Insert rows
for _, row in df.iterrows():
    sql = """
    INSERT IGNORE INTO used_cars (
        sales_id, name, year, price, mileage, region, state_or_province, city,
        fuel, seller_type, transmission, owner, engine, max_power, torque, seats, sold
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    values = (
        int(row['sales_id']),
        row['name'],
        int(row['year']),
        int(row['price']),
        float(row['mileage']),
        row['region'],
        row['state_or_province'],
        row['city'],
        row['fuel'],
        row['seller_type'],
        row['transmission'],
        row['owner'],
        row['engine'],
        row['max_power'],
        row['torque'],
        int(row['seats']) if not pd.isna(row['seats']) else None,
        bool(row['sold']) if not pd.isna(row['sold']) else None
    )
    cursor.execute(sql, values)

# Commit changes
conn.commit()
print("✅ Data inserted successfully!")

# Close connection
cursor.close()
conn.close()
# Out:
# ✅ Data inserted successfully!

# %%
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='root',
    database='UsedCarsDB'
)
cursor = conn.cursor()

# 1. Average price of used cars by brand, model, and year
def avg_price_by_brand_model_year():
    print("\n--- Average Price by Brand, Model, and Year ---")
    query = """
    SELECT 
        SUBSTRING_INDEX(name, ' ', 1) AS brand,
        name AS model,
        year,
        ROUND(AVG(price), 0) AS avg_price
    FROM used_cars
    GROUP BY brand, model, year
    ORDER BY avg_price DESC
    LIMIT 10;
    """
    cursor.execute(query)
    for row in cursor.fetchall():
        print(f"{row[0]} | {row[1]} | {row[2]} ➜ ₹{row[3]:,.0f}")

# 2. Most common car makes and models
def most_common_makes_models():
    print("\n--- Most Common Car Makes and Models ---")
    query = """
    SELECT name, COUNT(*) AS count
    FROM used_cars
    GROUP BY name
    ORDER BY count DESC
    LIMIT 10;
    """
    cursor.execute(query)
    for name, count in cursor.fetchall():
        print(f"{name}: {count} listings")

# 3. Price trends based on mileage and year
def price_trends_mileage_year():
    print("\n--- Price Trends Based on Mileage and Year ---")
    query = """
    SELECT year, ROUND(AVG(price), 0) AS avg_price, ROUND(AVG(mileage), 0) AS avg_mileage
    FROM used_cars
    GROUP BY year
    ORDER BY year ASC;
    """
    cursor.execute(query)
    for row in cursor.fetchall():
        print(f"Year {row[0]} ➜ Avg Price: ₹{row[1]:,.0f}, Avg Mileage: {row[2]:,} km")

# 4. Distribution of transmission types and fuel types
def distribution_transmission_fuel():
    print("\n--- Transmission Types Distribution ---")
    cursor.execute("SELECT transmission, COUNT(*) FROM used_cars GROUP BY transmission;")
    for transmission, count in cursor.fetchall():
        print(f"{transmission}: {count}")

    print("\n--- Fuel Types Distribution ---")
    cursor.execute("SELECT fuel, COUNT(*) FROM used_cars GROUP BY fuel;")
    for fuel, count in cursor.fetchall():
        print(f"{fuel}: {count}")

# 5. Best value cars based on price-to-mileage ratio
def best_value_cars():
    print("\n--- Best Value Cars (Based on Price-to-Mileage Ratio) ---")
    query = """
    SELECT name, year, price, mileage, ROUND(price / mileage, 2) AS ratio
    FROM used_cars
    WHERE mileage > 0
    ORDER BY ratio ASC
    LIMIT 10;
    """
    cursor.execute(query)
    for row in cursor.fetchall():
        print(f"{row[0]} ({row[1]}) ➜ ₹{row[2]:,.0f}, {row[3]:,} km ➜ Ratio: {row[4]}")

# Simple CLI menu
def analytical_menu():
    while True:
        print("\n====== Analytical Computation Menu ======")
        print("1. Average Price by Brand, Model, and Year")
        print("2. Most Common Car Makes and Models")
        print("3. Price Trends (Mileage & Year)")
        print("4. Transmission and Fuel Type Distribution")
        print("5. Best Value Cars (Price-to-Mileage Ratio)")
        print("6. Exit")

        choice = input("Choose an option (1-6): ")

        if choice == '1':
            avg_price_by_brand_model_year()
        elif choice == '2':
            most_common_makes_models()
        elif choice == '3':
            price_trends_mileage_year()
        elif choice == '4':
            distribution_transmission_fuel()
        elif choice == '5':
            best_value_cars()
        elif choice == '6':
            print("✅ Exiting Analytical Menu.")
            break
        else:
            print("❌ Invalid choice. Please try again.")

# Run the menu
analytical_menu()

# Close MySQL connection
cursor.close()
conn.close()
# Out:
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 1
#
# --- Average Price by Brand, Model, and Year ---
# Volvo | Volvo | 2017 ➜ ₹10,000,000
# BMW | BMW | 2020 ➜ ₹7,200,000
# Audi | Audi | 2019 ➜ ₹6,223,000
# BMW | BMW | 2019 ➜ ₹5,453,125
# Mercedes | Mercedes | 2019 ➜ ₹5,200,000
# Lexus | Lexus | 2019 ➜ ₹5,150,000
# BMW | BMW | 2018 ➜ ₹4,585,000
# Land | Land | 2019 ➜ ₹4,500,000
# Mercedes | Mercedes | 2017 ➜ ₹3,894,900
# Volvo | Volvo | 2019 ➜ ₹3,854,839
#
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 3
#
# --- Price Trends Based on Mileage and Year ---
# Year 1994 ➜ Avg Price: ₹72,000, Avg Mileage: 14.0 km
# Year 1995 ➜ Avg Price: ₹55,000, Avg Mileage: 16.0 km
# Year 1996 ➜ Avg Price: ₹41,000, Avg Mileage: 16.0 km
# Year 1997 ➜ Avg Price: ₹86,111, Avg Mileage: 16.0 km
# Year 1998 ➜ Avg Price: ₹57,889, Avg Mileage: 16.0 km
# Year 1999 ➜ Avg Price: ₹76,929, Avg Mileage: 16.0 km
# Year 2000 ➜ Avg Price: ₹76,461, Avg Mileage: 17.0 km
# Year 2001 ➜ Avg Price: ₹46,500, Avg Mileage: 17.0 km
# Year 2002 ➜ Avg Price: ₹103,789, Avg Mileage: 16.0 km
# Year 2003 ➜ Avg Price: ₹101,573, Avg Mileage: 16.0 km
# Year 2004 ➜ Avg Price: ₹109,409, Avg Mileage: 16.0 km
# Year 2005 ➜ Avg Price: ₹143,757, Avg Mileage: 16.0 km
# Year 2006 ➜ Avg Price: ₹170,462, Avg Mileage: 16.0 km
# Year 2007 ➜ Avg Price: ₹179,107, Avg Mileage: 17.0 km
# Year 2008 ➜ Avg Price: ₹206,219, Avg Mileage: 17.0 km
# Year 2009 ➜ Avg Price: ₹229,694, Avg Mileage: 17.0 km
# Year 2010 ➜ Avg Price: ₹275,226, Avg Mileage: 18.0 km
# Year 2011 ➜ Avg Price: ₹317,540, Avg Mileage: 18.0 km
# Year 2012 ➜ Avg Price: ₹353,143, Avg Mileage: 19.0 km
# Year 2013 ➜ Avg Price: ₹459,294, Avg Mileage: 19.0 km
# Year 2014 ➜ Avg Price: ₹516,489, Avg Mileage: 20.0 km
# Year 2015 ➜ Avg Price: ₹596,770, Avg Mileage: 20.0 km
# Year 2016 ➜ Avg Price: ₹700,318, Avg Mileage: 20.0 km
# Year 2017 ➜ Avg Price: ₹887,805, Avg Mileage: 21.0 km
# Year 2018 ➜ Avg Price: ₹958,184, Avg Mileage: 21.0 km
# Year 2019 ➜ Avg Price: ₹1,778,799, Avg Mileage: 20.0 km
# Year 2020 ➜ Avg Price: ₹888,096, Avg Mileage: 20.0 km
#
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 2
#
# --- Most Common Car Makes and Models ---
# Maruti: 2367 listings
# Hyundai: 1352 listings
# Mahindra: 756 listings
# Tata: 718 listings
# Honda: 466 listings
# Toyota: 452 listings
# Ford: 388 listings
# Chevrolet: 230 listings
# Renault: 228 listings
# Volkswagen: 183 listings
#
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 3
#
# --- Price Trends Based on Mileage and Year ---
# Year 1994 ➜ Avg Price: ₹72,000, Avg Mileage: 14.0 km
# Year 1995 ➜ Avg Price: ₹55,000, Avg Mileage: 16.0 km
# Year 1996 ➜ Avg Price: ₹41,000, Avg Mileage: 16.0 km
# Year 1997 ➜ Avg Price: ₹86,111, Avg Mileage: 16.0 km
# Year 1998 ➜ Avg Price: ₹57,889, Avg Mileage: 16.0 km
# Year 1999 ➜ Avg Price: ₹76,929, Avg Mileage: 16.0 km
# Year 2000 ➜ Avg Price: ₹76,461, Avg Mileage: 17.0 km
# Year 2001 ➜ Avg Price: ₹46,500, Avg Mileage: 17.0 km
# Year 2002 ➜ Avg Price: ₹103,789, Avg Mileage: 16.0 km
# Year 2003 ➜ Avg Price: ₹101,573, Avg Mileage: 16.0 km
# Year 2004 ➜ Avg Price: ₹109,409, Avg Mileage: 16.0 km
# Year 2005 ➜ Avg Price: ₹143,757, Avg Mileage: 16.0 km
# Year 2006 ➜ Avg Price: ₹170,462, Avg Mileage: 16.0 km
# Year 2007 ➜ Avg Price: ₹179,107, Avg Mileage: 17.0 km
# Year 2008 ➜ Avg Price: ₹206,219, Avg Mileage: 17.0 km
# Year 2009 ➜ Avg Price: ₹229,694, Avg Mileage: 17.0 km
# Year 2010 ➜ Avg Price: ₹275,226, Avg Mileage: 18.0 km
# Year 2011 ➜ Avg Price: ₹317,540, Avg Mileage: 18.0 km
# Year 2012 ➜ Avg Price: ₹353,143, Avg Mileage: 19.0 km
# Year 2013 ➜ Avg Price: ₹459,294, Avg Mileage: 19.0 km
# Year 2014 ➜ Avg Price: ₹516,489, Avg Mileage: 20.0 km
# Year 2015 ➜ Avg Price: ₹596,770, Avg Mileage: 20.0 km
# Year 2016 ➜ Avg Price: ₹700,318, Avg Mileage: 20.0 km
# Year 2017 ➜ Avg Price: ₹887,805, Avg Mileage: 21.0 km
# Year 2018 ➜ Avg Price: ₹958,184, Avg Mileage: 21.0 km
# Year 2019 ➜ Avg Price: ₹1,778,799, Avg Mileage: 20.0 km
# Year 2020 ➜ Avg Price: ₹888,096, Avg Mileage: 20.0 km
#
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 4
#
# --- Transmission Types Distribution ---
# Manual: 6854
# Automatic: 1035
#
# --- Fuel Types Distribution ---
# Diesel: 4293
# Petrol: 3509
# LPG: 35
# CNG: 52
#
# ====== Analytical Computation Menu ======
# 1. Average Price by Brand, Model, and Year
# 2. Most Common Car Makes and Models
# 3. Price Trends (Mileage & Year)
# 4. Transmission and Fuel Type Distribution
# 5. Best Value Cars (Price-to-Mileage Ratio)
# 6. Exit
# Choose an option (1-6): 6
# ✅ Exiting Analytical Menu.

# %%
df.isnull().sum()

# %%
print(df.columns)
# Out:
# Index(['sales_id', 'name', 'year', 'price', 'km_driven', 'region',
#        'state_or_province', 'city', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'torque', 'seats', 'sold',
#        'price_to_mileage_ratio'],
#       dtype='object')

# %%
from sqlalchemy import create_engine, text

# Replace with your actual connection string
engine = create_engine('sqlite:///UsedCarsDB')

# Name of the table to drop
table_name = 'used_cars'

with engine.connect() as conn:
    conn.execute(text(f"DROP TABLE IF EXISTS {table_name}"))
    print(f"✅ Table '{table_name}' dropped successfully.")
# Out:
# ✅ Table 'used_cars' dropped successfully.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset

# Calculate price_to_mileage_ratio
df['price_to_mileage_ratio'] = df['price'] / df['km_driven']

def summary_stats():
    print("\n--- Summary Statistics ---")
    print(df[['price', 'km_driven']].describe())

    print("\n--- Mode Statistics ---")
    print(df.mode().iloc[0])

def top_models():
    print("\n--- Top 10 Most Listed Car Models ---")
    top_10 = df['name'].value_counts().head(10)
    print(top_10)

    # Bar Chart
    top_10.plot(kind='bar', figsize=(10, 5), color='skyblue')
    plt.title('Top 10 Most Listed Car Models')
    plt.ylabel('Count')
    plt.xlabel('Car Model')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

def best_resale_value():
    print("\n--- Top 10 Cars with Best Resale Value ---")
    top_resale = df[['name', 'year', 'price', 'km_driven', 'price_to_mileage_ratio']] \
        .sort_values(by='price_to_mileage_ratio') \
        .head(10)
    print(top_resale)

    # Bar chart of resale value
    plt.figure(figsize=(10, 5))
    sns.barplot(x='name', y='price_to_mileage_ratio', data=top_resale, palette='viridis')
    plt.title('Best Resale Value Cars (Low Price-to-Mileage Ratio)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
def market_trends():
    print("\n--- Market Trends ---")

    # Average Car Price by Year
    avg_price_by_year = df.groupby('year')['price'].mean().reset_index()

    plt.figure(figsize=(12, 6))
    sns.barplot(data=avg_price_by_year, x='year', y='price', palette='Blues_d')
    plt.title(' Average Car Price by Year')
    plt.xlabel('Year')
    plt.ylabel('Average Price (₹)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Average Price by Mileage Buckets
    mileage_bins = pd.cut(df['mileage'], bins=[0, 10, 15, 20, 25, 30, 50], labels=['0-10', '10-15', '15-20', '20-25', '25-30', '30+'])
    df['mileage_group'] = mileage_bins
    avg_price_by_mileage = df.groupby('mileage_group')['price'].mean().reset_index()

    plt.figure(figsize=(10, 6))
    sns.barplot(data=avg_price_by_mileage, x='mileage_group', y='price', palette='Greens_d')
    plt.title(' Average Car Price by Mileage Group (km/l)')
    plt.xlabel('Mileage Group (km/l)')
    plt.ylabel('Average Price (₹)')
    plt.tight_layout()
    plt.show()



def buyer_preferences():
    print("\n--- Transmission Type Distribution ---")
    plt.figure(figsize=(8, 5))
    sns.countplot(x='transmission', data=df, palette='Set2')
    plt.title("Transmission Types")
    plt.tight_layout()
    plt.show()

    print("\n--- Fuel Type Distribution ---")
    plt.figure(figsize=(8, 5))
    sns.countplot(x='fuel', data=df, palette='Set3')
    plt.title("Fuel Types")
    plt.tight_layout()
    plt.show()

def main_menu():
    while True:
        print("\n========== Used Car Insights Menu ==========")
        print("1. Summary Statistics and Key Metrics")
        print("2. Top 10 Most Listed Car Models")
        print("3. Cars Offering the Best Resale Value")
        print("4. Market Trends (Price vs Year and Mileage)")
        print("5. Buyer Preferences (Transmission/Fuel)")
        print("6. Exit")

        choice = input("Enter your choice (1-6): ")

        if choice == '1':
            summary_stats()
        elif choice == '2':
            top_models()
        elif choice == '3':
            best_resale_value()
        elif choice == '4':
            market_trends()
        elif choice == '5':
            buyer_preferences()
        elif choice == '6':
            print("Exiting... Thank you!")
            break
        else:
            print("Invalid input. Please enter a number from 1 to 6.")

# Run the interactive menu
main_menu()
# Out:
# ========== Used Car Insights Menu ==========
# 1. Summary Statistics and Key Metrics
# 2. Top 10 Most Listed Car Models
# 3. Cars Offering the Best Resale Value
# 4. Market Trends (Price vs Year and Mileage)
# 5. Buyer Preferences (Transmission/Fuel)
# 6. Exit
# Enter your choice (1-6): 3
#
# --- Top 10 Cars with Best Resale Value ---
#          name  year   price  km_driven  price_to_mileage_ratio
# 6580     Tata  2004   50000     271000                0.184502
# 3370  Hyundai  2007  550000    2360457                0.233006
# 7137     Ford  2006   55000     201000                0.273632
# 5511   Maruti  2000   50000     180000                0.277778
# 1867   Maruti  2004   31504     110000                0.286400
# 2665   Maruti  2004   70000     220000                0.318182
# 4565     Tata  2004   80000     248200                0.322321
# 7459   Maruti  2006   65000     198000                0.328283
# 3906   Daewoo  2001   45000     137000                0.328467
# 2517   Maruti  2003   55000     167000                0.329341
# ========== Used Car Insights Menu ==========
# 1. Summary Statistics and Key Metrics
# 2. Top 10 Most Listed Car Models
# 3. Cars Offering the Best Resale Value
# 4. Market Trends (Price vs Year and Mileage)
# 5. Buyer Preferences (Transmission/Fuel)
# 6. Exit
# Enter your choice (1-6): 4
#
# --- Market Trends ---
# ========== Used Car Insights Menu ==========
# 1. Summary Statistics and Key Metrics
# 2. Top 10 Most Listed Car Models
# 3. Cars Offering the Best Resale Value
# 4. Market Trends (Price vs Year and Mileage)
# 5. Buyer Preferences (Transmission/Fuel)
# 6. Exit
# Enter your choice (1-6): 6
# Exiting... Thank you!
